# %% [markdown]
# <a href="https://colab.research.google.com/github/Kapisa1999/201-project/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

text = "hello everyone. hope all are fine"
print(sent_tokenize(text))
# Out:
# ['Artificial Intelligence is transforming industries.', 'NLP is a key part of AI.', 'Tokenization is the first NLP step.']

# %%
from nltk.tokenize import word_tokenize

text = "hello everyone. hope all are fine"
print(word_tokenize(text))
# Out:
# ['hello', 'everyone', '.', 'hope', 'all', 'are', 'fine']

# %%
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
word = "running"

stemmed_words = stemmer.stem(word)
print(stemmed_words)
# Out:
# run

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
word = "easily"

lemmatized_words = lemmatizer.lemmatize(word)
print(lemmatized_words)
# Out:
# easily
